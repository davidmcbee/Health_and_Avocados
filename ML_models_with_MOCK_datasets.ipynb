# %% [markdown]
# ### Unsupervised ML

# %%
# Initial imports
import pandas as pd
import hvplot.pandas
from path import Path
import plotly.express as px
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-1083e8ce8e0d> in <module>
#       1 # Initial imports
#       2 import pandas as pd
# ----> 3 import hvplot.pandas
#       4 from path import Path
#       5 import plotly.express as px
#
# ModuleNotFoundError: No module named 'hvplot'

# %%
# Load the crypto_data.csv dataset.
avocado_mock_df = pd.read_csv("Resources/MockDataset_Avocado_ML.csv")
avocado_mock_df.head(10)
# Out:
#    REGION (city)  LATITUDE  LONGITUDE DATE (Month + Year)  4046 Units sold  \
# 0    Los Angeles   34.0522   118.2437            1/1/2017       1223299.39
# 1      San Diego   32.7157   117.1611            1/1/2017        149666.20
# 2  San Francisco   37.7749   122.4194            1/1/2017        260100.73
# 3     Sacramento   38.5816   121.4944            1/1/2017        144876.31
# 4    Los Angeles   34.0522   118.2437            2/1/2017       5470227.08
# 5      San Diego   32.7157   117.1611            2/1/2017        260418.91
# 6  San Francisco   37.7749   122.4194            2/1/2017        560686.25
# 7     Sacramento   38.5816   121.4944            2/1/2017        321474.22
# 8    Los Angeles   34.0522   118.2437            3/1/2017       2768930.88
# 9      San Diego   32.7157   117.1611            3/1/2017        163424.69
#
#    4225 Units  4770 Units   Bags sold  CLIMATE_CA_pcp  CLIMATE_CA_tmin  ...  \
# ...

# %%
# Check data types
avocado_mock_df.dtypes
# Out:
# REGION (city)                        object
# LATITUDE                            float64
# LONGITUDE                           float64
# DATE (Month + Year)                  object
# 4046 Units sold                     float64
# 4225 Units                          float64
# 4770 Units                          float64
# Bags sold                           float64
# CLIMATE_CA_pcp                      float64
# CLIMATE_CA_tmin                     float64
# CLIMATE_CA_tmax                     float64
# TOTAL_VOLUME                          int64
# CALIFORNIA PRODUCTION                 int64
# CHILE PRODUCTION                      int64
# MEXICO PRODUCTION                     int64
# PERU PRODUCTION                       int64
# COLUMBIA PRODUCTION                   int64
# IMPORTS BY VALUE ($1000)              int64
# IMPORTS BY VOLUME (1000 LBS)        float64
# IMPORTS UNIT VALUE ($ PER POUND)    float64
# EXPORTS BY VALUE ($1000)              int64
# ...

# %%
# Count Null values
#avocado_mock_df.isnull().sum()

# %%
# Use get_dummies() to create variables for text features.
X = pd.get_dummies(avocado_mock_df,  columns=["REGION (city)","DATE (Month + Year)"])
print(X.shape)
X.head(10)
# Out:
# (12, 30)
#    LATITUDE  LONGITUDE  4046 Units sold  4225 Units  4770 Units   Bags sold  \
# 0   34.0522   118.2437       1223299.39   829896.69    56808.74  1441332.35
# 1   32.7157   117.1611        149666.20   206181.12    15014.45   189448.58
# 2   37.7749   122.4194        260100.73   717625.67     2490.66    66958.27
# 3   38.5816   121.4944        144876.31   339664.16      660.97    41564.20
# 4   34.0522   118.2437       5470227.08  1741607.02   937331.61  2701609.82
# 5   32.7157   117.1611        260418.91   290223.93    20313.95   321784.08
# 6   37.7749   122.4194        560686.25   900172.65    21331.13    75785.02
# 7   38.5816   121.4944        321474.22   418158.93    11962.44    57213.28
# 8   34.0522   118.2437       2768930.88   897311.08   518369.51  1269943.15
# 9   32.7157   117.1611        163424.69   176304.67    19186.14   158785.76
#
#    CLIMATE_CA_pcp  CLIMATE_CA_tmin  CLIMATE_CA_tmax  TOTAL_VOLUME  ...  \
# ...

# %%
# Standardize the data with StandardScaler().
avocado_mock_df_scaled = StandardScaler().fit_transform(X)
avocado_mock_df_scaled[0:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-4e596e04eeea> in <module>
#       1 # Standardize the data with StandardScaler().
# ----> 2 avocado_mock_df_scaled = StandardScaler().fit_transform(X)
#       3 avocado_mock_df_scaled[0:5]
#
# NameError: name 'StandardScaler' is not defined

# %%
# Using PCA to reduce dimension to three principal components.
pca = PCA(n_components=3)
crypto_pca = pca.fit_transform(crypto_scaled)
crypto_pca
