# %% [markdown]
# ### Purpose of ML models: forcasting avocado prices

# %% [markdown]
# ### Starting with Linear Regression in sckit-learn, then comparing models with Random Forest Regressor and Neural Network.
#
# (Features) **X-variables**: region, date, units sold, production data.
#
# (Target) **y-variable:** avocado price
#
# Next step is research libraries Random Forest Regressor (predicting acctual price) and Classifier (binning y-variable in n-categories.

# %% [markdown]
# ## Linear Regression with sckit-learn

# %%
# Import dependencies.
import pandas as pd
import numpy as np
from collections import Counter
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ### Importing data from the database

# %%
import pandas as pd
from sqlalchemy import create_engine
from config import db_password

# local server connection string
db_string = f"postgres://postgres:{db_password}@127.0.0.1:5432/avocados"

# create db engine
engine = create_engine(db_string)

# %%
# Load the avocado dataset form pgAdmin.
avocado_df = pd.read_sql_table('all_prices_prod', engine)
avocado_df.head()
# Out:
#   geography       date          type  avg_price  total_volume  units_4046  \
# 0    Albany  1/15/2017  conventional       1.55      88526.26     3327.65
# 1    Albany  1/15/2017       organic       1.84       1982.65       82.30
# 2    Albany   1/2/2017  conventional       1.47     129948.23     4845.77
# 3    Albany   1/2/2017       organic       1.87       1376.70       71.65
# 4    Albany  1/22/2017  conventional       1.59     128679.24     4119.94
#
#    units_4225  units_4770_  total_bags    s_bags  l_bags  xl_bags year_month  \
# 0    71956.77       607.03    12634.81  12574.72   60.09     0.00       None
# 1      328.02         0.00     1572.33   1572.33    0.00     0.00       None
# 2   117027.41       200.36     7874.69   7866.86    7.83     0.00       None
# 3      192.63         0.00     1112.42   1112.42    0.00     0.00       None
# 4   111173.08      2191.71    11194.51  11060.19  125.50     8.82       None
#
#   status  total_volume_produces  california  chile  mexico  peru  columbia
# 0   None                    NaN         NaN    NaN     NaN   NaN       NaN
# 1   None                    NaN         NaN    NaN     NaN   NaN       NaN
# 2   None                    NaN         NaN    NaN     NaN   NaN       NaN
# 3   None                    NaN         NaN    NaN     NaN   NaN       NaN
# 4   None                    NaN         NaN    NaN     NaN   NaN       NaN

# %%
# Change None values to NaN.
avocado_df = avocado_df.fillna(value=np.nan)
#avocado_df.head()

# %%
# Make a copy
avocado_df = avocado_df.copy()

# %%
# Count Null values
#avocado_df.isnull().sum()

# Drop Null values
avocado_df = avocado_df.dropna(how='any')
print(avocado_df.shape)
avocado_df.head()
# Out:
# (14688, 20)
#     geography       date          type  avg_price  total_volume  units_4046  \
# 542    Albany  1/14/2018  conventional       1.42      95246.38     2897.41
# 543    Albany  1/14/2018       organic       1.47       4140.95        7.30
# 544    Albany  1/21/2018  conventional       1.69     135196.35     3133.37
# 545    Albany  1/21/2018       organic       1.54       3346.54       14.67
# 546    Albany  1/28/2018  conventional       1.57      93625.03     3101.17
#
#      units_4225  units_4770_  total_bags    s_bags   l_bags  xl_bags  \
# 542    76570.67        44.00    15734.30  10012.80  5721.50     0.00
# 543      301.87         0.00     3831.78   3831.78     0.00     0.00
# 544   116520.88        88.78    15453.32  10023.79  5429.53     0.00
# 545      253.01         0.00     3078.86   3078.86     0.00     0.00
# 546    74627.23        55.59    15841.04  11614.79  4159.58    66.67
#
#     year_month  status  total_volume_produces  california     chile  \
# 542   1/1/2018  actual             52758905.0    830821.0  449003.0
# 543   1/1/2018  actual             52758905.0    830821.0  449003.0
# 544   1/1/2018  actual             54698266.0   2913663.0  445127.0
# 545   1/1/2018  actual             54698266.0   2913663.0  445127.0
# 546   1/1/2018  actual             45299201.0   2698356.0   95491.0
#
#          mexico  peru  columbia
# 542  51479081.0   0.0       0.0
# 543  51479081.0   0.0       0.0
# 544  51339476.0   0.0       0.0
# 545  51339476.0   0.0       0.0
# 546  42505354.0   0.0       0.0

# %%
# Count Null values
#avocado_df.isnull().sum()

# Drop Null values
avocado_df = avocado_df.dropna(how='any')
print(avocado_df.shape)
avocado_df.head()
# Out:
# (14688, 20)
#     geography       date          type  avg_price  total_volume  units_4046  \
# 542    Albany  1/14/2018  conventional       1.42      95246.38     2897.41
# 543    Albany  1/14/2018       organic       1.47       4140.95        7.30
# 544    Albany  1/21/2018  conventional       1.69     135196.35     3133.37
# 545    Albany  1/21/2018       organic       1.54       3346.54       14.67
# 546    Albany  1/28/2018  conventional       1.57      93625.03     3101.17
#
#      units_4225  units_4770_  total_bags    s_bags   l_bags  xl_bags  \
# 542    76570.67        44.00    15734.30  10012.80  5721.50     0.00
# 543      301.87         0.00     3831.78   3831.78     0.00     0.00
# 544   116520.88        88.78    15453.32  10023.79  5429.53     0.00
# 545      253.01         0.00     3078.86   3078.86     0.00     0.00
# 546    74627.23        55.59    15841.04  11614.79  4159.58    66.67
#
#     year_month  status  total_volume_produces  california     chile  \
# 542   1/1/2018  actual             52758905.0    830821.0  449003.0
# 543   1/1/2018  actual             52758905.0    830821.0  449003.0
# 544   1/1/2018  actual             54698266.0   2913663.0  445127.0
# 545   1/1/2018  actual             54698266.0   2913663.0  445127.0
# 546   1/1/2018  actual             45299201.0   2698356.0   95491.0
#
#          mexico  peru  columbia
# 542  51479081.0   0.0       0.0
# 543  51479081.0   0.0       0.0
# 544  51339476.0   0.0       0.0
# 545  51339476.0   0.0       0.0
# 546  42505354.0   0.0       0.0

# %%
# List all columns
avocado_df.columns.tolist()
# Out:
# ['geography',
#  'date',
#  'type',
#  'avg_price',
#  'total_volume',
#  'units_4046',
#  'units_4225',
#  'units_4770_',
#  'total_bags',
#  's_bags',
#  'l_bags',
#  'xl_bags',
#  'year_month',
#  'status',
#  'total_volume_produces',
#  'california',
#  'chile',
#  'mexico',
#  'peru',
#  'columbia']

# %%
# Drop the non-beneficial columns.
avocado_df.drop(columns=["year_month"], inplace=True)
#avocado_df.head()

# %%
# Rename confusing columns
avocado_df = avocado_df.rename(columns={'total_volume':'total_volume_sold', 'total_volume_produces':'total_volume_produced', 'units_4770_':'units_4770' })
#avocado_df.head()

# %%
# Check datatypes
avocado_df.dtypes
# Out:
# geography                 object
# date                      object
# type                      object
# avg_price                float64
# total_volume_sold        float64
# units_4046               float64
# units_4225               float64
# units_4770               float64
# total_bags               float64
# s_bags                   float64
# l_bags                   float64
# xl_bags                  float64
# status                    object
# total_volume_produced    float64
# california               float64
# chile                    float64
# mexico                   float64
# peru                     float64
# columbia                 float64
# dtype: object

# %%
# Convert date object to date and check datatype
import datetime
avocado_df.date = avocado_df.date.apply(pd.to_datetime)
print(avocado_df.date.dtypes)
# Out:
# datetime64[ns]

# %%
# Exctract the month
avocado_df['month'] = avocado_df.date.dt.month
avocado_df.head()
# Out:
#     geography       date          type  avg_price  total_volume_sold  \
# 542    Albany 2018-01-14  conventional       1.42           95246.38
# 543    Albany 2018-01-14       organic       1.47            4140.95
# 544    Albany 2018-01-21  conventional       1.69          135196.35
# 545    Albany 2018-01-21       organic       1.54            3346.54
# 546    Albany 2018-01-28  conventional       1.57           93625.03
#
#      units_4046  units_4225  units_4770  total_bags    s_bags   l_bags  \
# 542     2897.41    76570.67       44.00    15734.30  10012.80  5721.50
# 543        7.30      301.87        0.00     3831.78   3831.78     0.00
# 544     3133.37   116520.88       88.78    15453.32  10023.79  5429.53
# 545       14.67      253.01        0.00     3078.86   3078.86     0.00
# 546     3101.17    74627.23       55.59    15841.04  11614.79  4159.58
#
#      xl_bags  status  total_volume_produced  california     chile      mexico  \
# 542     0.00  actual             52758905.0    830821.0  449003.0  51479081.0
# 543     0.00  actual             52758905.0    830821.0  449003.0  51479081.0
# 544     0.00  actual             54698266.0   2913663.0  445127.0  51339476.0
# 545     0.00  actual             54698266.0   2913663.0  445127.0  51339476.0
# 546    66.67  actual             45299201.0   2698356.0   95491.0  42505354.0
#
#      peru  columbia  month
# 542   0.0       0.0      1
# 543   0.0       0.0      1
# 544   0.0       0.0      1
# 545   0.0       0.0      1
# 546   0.0       0.0      1

# %%
# # Exctract the week with no warning
# avocado_df['week'] = avocado_df.date.dt.isocalendar().week
# avocado_df.head()

# %%
# Check the datatypes for month
#print(avocado_df.week.dtypes)

# %%
#Check the weeks
#avocado_df.week.value_counts()

# %%
# Exctract the week
avocado_df['week'] = avocado_df.date.dt.week
avocado_df.head()
# Out:
# C:\Users\sfand\anaconda3\envs\pythonml\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#     geography       date          type  avg_price  total_volume_sold  \
# 542    Albany 2018-01-14  conventional       1.42           95246.38
# 543    Albany 2018-01-14       organic       1.47            4140.95
# 544    Albany 2018-01-21  conventional       1.69          135196.35
# 545    Albany 2018-01-21       organic       1.54            3346.54
# 546    Albany 2018-01-28  conventional       1.57           93625.03
#
#      units_4046  units_4225  units_4770  total_bags    s_bags  ...  xl_bags  \
# 542     2897.41    76570.67       44.00    15734.30  10012.80  ...     0.00
# 543        7.30      301.87        0.00     3831.78   3831.78  ...     0.00
# 544     3133.37   116520.88       88.78    15453.32  10023.79  ...     0.00
# 545       14.67      253.01        0.00     3078.86   3078.86  ...     0.00
# 546     3101.17    74627.23       55.59    15841.04  11614.79  ...    66.67
#
#      status total_volume_produced  california     chile      mexico  peru  \
# 542  actual            52758905.0    830821.0  449003.0  51479081.0   0.0
# 543  actual            52758905.0    830821.0  449003.0  51479081.0   0.0
# 544  actual            54698266.0   2913663.0  445127.0  51339476.0   0.0
# 545  actual            54698266.0   2913663.0  445127.0  51339476.0   0.0
# 546  actual            45299201.0   2698356.0   95491.0  42505354.0   0.0
#
#      columbia  month  week
# 542       0.0      1     2
# 543       0.0      1     2
# 544       0.0      1     3
# 545       0.0      1     3
# 546       0.0      1     4
#
# [5 rows x 21 columns]

# %%
# Check the datatypes for month
print(avocado_df.week.dtypes)
# Out:
# int64

# %%
#Check the months
#avocado_df.month.value_counts()

#Check the weeks
#avocado_df.week.value_counts()

# %%
# Select and count rows with Total U.S. (see EDA in Tableau - possible outlier) 
avocado_df_no_TotalUS_check = avocado_df[avocado_df['geography'].str.contains('Total U.S.')]
#len(avocado_df_no_TotalUS)
#avocado_df_no_TotalUS_check.head()

# %%
# Drop rows with Total U.S. (see EDA in Tableau - possible outlier) 
avocado_df_no_TotalUS = avocado_df[~avocado_df['geography'].isin(['Total U.S.'])]
avocado_df_no_TotalUS.head()
# Out:
#     geography       date          type  avg_price  total_volume_sold  \
# 542    Albany 2018-01-14  conventional       1.42           95246.38
# 543    Albany 2018-01-14       organic       1.47            4140.95
# 544    Albany 2018-01-21  conventional       1.69          135196.35
# 545    Albany 2018-01-21       organic       1.54            3346.54
# 546    Albany 2018-01-28  conventional       1.57           93625.03
#
#      units_4046  units_4225  units_4770  total_bags    s_bags  ...  xl_bags  \
# 542     2897.41    76570.67       44.00    15734.30  10012.80  ...     0.00
# 543        7.30      301.87        0.00     3831.78   3831.78  ...     0.00
# 544     3133.37   116520.88       88.78    15453.32  10023.79  ...     0.00
# 545       14.67      253.01        0.00     3078.86   3078.86  ...     0.00
# 546     3101.17    74627.23       55.59    15841.04  11614.79  ...    66.67
#
#      status total_volume_produced  california     chile      mexico  peru  \
# 542  actual            52758905.0    830821.0  449003.0  51479081.0   0.0
# 543  actual            52758905.0    830821.0  449003.0  51479081.0   0.0
# 544  actual            54698266.0   2913663.0  445127.0  51339476.0   0.0
# 545  actual            54698266.0   2913663.0  445127.0  51339476.0   0.0
# 546  actual            45299201.0   2698356.0   95491.0  42505354.0   0.0
#
#      columbia  month  week
# 542       0.0      1     2
# 543       0.0      1     2
# 544       0.0      1     3
# 545       0.0      1     3
# 546       0.0      1     4
#
# [5 rows x 21 columns]

# %%
print(avocado_df_no_TotalUS.shape)
# Out:
# (14416, 21)

# %%
# Calculations
### sumup all units sold
### calculate ratio total volume sold vs total_volume_produced

### sumup all units sold
avocado_df_no_TotalUS['total_units_sold'] = avocado_df_no_TotalUS.iloc[:, 5:8].sum(axis=1)

### calculate ratio total volume sold vs total_volume_produced
avocado_df_no_TotalUS['ratio_sold_vs_produced'] = avocado_df_no_TotalUS['total_volume_sold']/avocado_df_no_TotalUS['total_volume_produced']
avocado_df_no_TotalUS.head()
# Out:
# C:\Users\sfand\anaconda3\envs\pythonml\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\sfand\anaconda3\envs\pythonml\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#     geography       date          type  avg_price  total_volume_sold  \
# 542    Albany 2018-01-14  conventional       1.42           95246.38
# 543    Albany 2018-01-14       organic       1.47            4140.95
# 544    Albany 2018-01-21  conventional       1.69          135196.35
# 545    Albany 2018-01-21       organic       1.54            3346.54
# 546    Albany 2018-01-28  conventional       1.57           93625.03
#
#      units_4046  units_4225  units_4770  total_bags    s_bags  ...  \
# 542     2897.41    76570.67       44.00    15734.30  10012.80  ...
# 543        7.30      301.87        0.00     3831.78   3831.78  ...
# 544     3133.37   116520.88       88.78    15453.32  10023.79  ...
# 545       14.67      253.01        0.00     3078.86   3078.86  ...
# 546     3101.17    74627.23       55.59    15841.04  11614.79  ...
#
#      total_volume_produced  california     chile      mexico  peru  columbia  \
# 542             52758905.0    830821.0  449003.0  51479081.0   0.0       0.0
# 543             52758905.0    830821.0  449003.0  51479081.0   0.0       0.0
# 544             54698266.0   2913663.0  445127.0  51339476.0   0.0       0.0
# 545             54698266.0   2913663.0  445127.0  51339476.0   0.0       0.0
# 546             45299201.0   2698356.0   95491.0  42505354.0   0.0       0.0
#
#      month  week  total_units_sold  ratio_sold_vs_produced
# 542      1     2          79512.08                0.001805
# 543      1     2            309.17                0.000078
# 544      1     3         119743.03                0.002472
# 545      1     3            267.68                0.000061
# 546      1     4          77783.99                0.002067
#
# [5 rows x 23 columns]

# %%
# Clean the type_conventional.
## Count the values
avocado_df_no_TotalUS["type"].value_counts()
# Out:
# organic          7208
# conventional     4240
# conventional     2968
# Name: type, dtype: int64

# %%
# Replace "conventional " with "conventional"
avocado_df_no_TotalUS["type"] = avocado_df_no_TotalUS["type"].str.replace("conventional ", "conventional")
# Out:
# C:\Users\sfand\anaconda3\envs\pythonml\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
avocado_df_no_TotalUS["type"].value_counts()
# Out:
# conventional    7208
# organic         7208
# Name: type, dtype: int64

# %%
# Plot the data with encoded date grouped by month. - check also for scatter plot
#avocado_df.groupby('month')['ratio CA sold vs prod'].mean().plot()

# %% [markdown]
# ### DATA preprocessing for ML model

# %%
# Check datatypes
avocado_df_no_TotalUS.dtypes
# Out:
# geography                         object
# date                      datetime64[ns]
# type                              object
# avg_price                        float64
# total_volume_sold                float64
# units_4046                       float64
# units_4225                       float64
# units_4770                       float64
# total_bags                       float64
# s_bags                           float64
# l_bags                           float64
# xl_bags                          float64
# status                            object
# total_volume_produced            float64
# california                       float64
# chile                            float64
# mexico                           float64
# peru                             float64
# columbia                         float64
# month                              int64
# week                               int64
# total_units_sold                 float64
# ratio_sold_vs_produced           float64
# dtype: object

# %%
# Use get_dummies() to create variables for text features.
avocado_cat_encoded = pd.get_dummies(avocado_df_no_TotalUS,  columns=["geography", "type", "status"])
avocado_cat_encoded.head()
# Out:
#           date  avg_price  total_volume_sold  units_4046  units_4225  \
# 542 2018-01-14       1.42           95246.38     2897.41    76570.67
# 543 2018-01-14       1.47            4140.95        7.30      301.87
# 544 2018-01-21       1.69          135196.35     3133.37   116520.88
# 545 2018-01-21       1.54            3346.54       14.67      253.01
# 546 2018-01-28       1.57           93625.03     3101.17    74627.23
#
#      units_4770  total_bags    s_bags   l_bags  xl_bags  ...  \
# 542       44.00    15734.30  10012.80  5721.50     0.00  ...
# 543        0.00     3831.78   3831.78     0.00     0.00  ...
# 544       88.78    15453.32  10023.79  5429.53     0.00  ...
# 545        0.00     3078.86   3078.86     0.00     0.00  ...
# 546       55.59    15841.04  11614.79  4159.58    66.67  ...
#
#      geography_Southeast  geography_Spokane  geography_St. Louis  \
# 542                    0                  0                    0
# 543                    0                  0                    0
# 544                    0                  0                    0
# 545                    0                  0                    0
# 546                    0                  0                    0
#
#      geography_Syracuse  geography_Tampa  geography_West  \
# 542                   0                0               0
# 543                   0                0               0
# 544                   0                0               0
# 545                   0                0               0
# 546                   0                0               0
#
#      geography_West Tex/New Mexico  type_conventional  type_organic  \
# 542                              0                  1             0
# 543                              0                  0             1
# 544                              0                  1             0
# 545                              0                  0             1
# 546                              0                  1             0
#
#      status_actual
# 542              1
# 543              1
# 544              1
# 545              1
# 546              1
#
# [5 rows x 76 columns]

# %%
#List the columns
avocado_cat_encoded.columns.tolist()
# Out:
# ['date',
#  'avg_price',
#  'total_volume_sold',
#  'units_4046',
#  'units_4225',
#  'units_4770',
#  'total_bags',
#  's_bags',
#  'l_bags',
#  'xl_bags',
#  'total_volume_produced',
#  'california',
#  'chile',
#  'mexico',
#  'peru',
#  'columbia',
#  'month',
#  'week',
#  'total_units_sold',
#  'ratio_sold_vs_produced',
#  'geography_Albany',
#  'geography_Atlanta',
#  'geography_Baltimore/Washington',
#  'geography_Boise',
#  'geography_Boston',
#  'geography_Buffalo/Rochester',
#  'geography_California',
#  'geography_Charlotte',
#  'geography_Chicago',
#  'geography_Cincinnati/Dayton',
#  'geography_Columbus',
#  'geography_Dallas/Ft. Worth',
#  'geography_Denver',
#  'geography_Detroit',
#  'geography_Grand Rapids',
#  'geography_Great Lakes',
#  'geography_Harrisburg/Scranton',
#  'geography_Hartford/Springfield',
#  'geography_Houston',
#  'geography_Indianapolis',
#  'geography_Jacksonville',
#  'geography_Las Vegas',
#  'geography_Los Angeles',
#  'geography_Louisville',
#  'geography_Miami/Ft. Lauderdale',
#  'geography_Midsouth',
#  'geography_Nashville',
#  'geography_New Orleans/Mobile',
#  'geography_New York',
#  'geography_Northeast',
#  'geography_Northern New England',
#  'geography_Orlando',
#  'geography_Philadelphia',
#  'geography_Phoenix/Tucson',
#  'geography_Pittsburgh',
#  'geography_Plains',
#  'geography_Portland',
#  'geography_Raleigh/Greensboro',
#  'geography_Richmond/Norfolk',
#  'geography_Roanoke',
#  'geography_Sacramento',
#  'geography_San Diego',
#  'geography_San Francisco',
#  'geography_Seattle',
#  'geography_South Carolina',
#  'geography_South Central',
#  'geography_Southeast',
#  'geography_Spokane',
#  'geography_St. Louis',
#  'geography_Syracuse',
#  'geography_Tampa',
#  'geography_West',
#  'geography_West Tex/New Mexico',
#  'type_conventional',
#  'type_organic',
#  'status_actual']

# %%
# Drop the non-beneficial columns - drop "prod_total_volume" after the ratio calculations
avocado_cat_encoded.drop(columns=["date", "total_volume_produced"], inplace=True)
avocado_cat_encoded.head()
# Out:
#      avg_price  total_volume_sold  units_4046  units_4225  units_4770  \
# 542       1.42           95246.38     2897.41    76570.67       44.00
# 543       1.47            4140.95        7.30      301.87        0.00
# 544       1.69          135196.35     3133.37   116520.88       88.78
# 545       1.54            3346.54       14.67      253.01        0.00
# 546       1.57           93625.03     3101.17    74627.23       55.59
#
#      total_bags    s_bags   l_bags  xl_bags  california  ...  \
# 542    15734.30  10012.80  5721.50     0.00    830821.0  ...
# 543     3831.78   3831.78     0.00     0.00    830821.0  ...
# 544    15453.32  10023.79  5429.53     0.00   2913663.0  ...
# 545     3078.86   3078.86     0.00     0.00   2913663.0  ...
# 546    15841.04  11614.79  4159.58    66.67   2698356.0  ...
#
#      geography_Southeast  geography_Spokane  geography_St. Louis  \
# 542                    0                  0                    0
# 543                    0                  0                    0
# 544                    0                  0                    0
# 545                    0                  0                    0
# 546                    0                  0                    0
#
#      geography_Syracuse  geography_Tampa  geography_West  \
# 542                   0                0               0
# 543                   0                0               0
# 544                   0                0               0
# 545                   0                0               0
# 546                   0                0               0
#
#      geography_West Tex/New Mexico  type_conventional  type_organic  \
# 542                              0                  1             0
# 543                              0                  0             1
# 544                              0                  1             0
# 545                              0                  0             1
# 546                              0                  1             0
#
#      status_actual
# 542              1
# 543              1
# 544              1
# 545              1
# 546              1
#
# [5 rows x 74 columns]

# %%
# Determine the number of unique values in each column.
#avocado_cat_encoded.dtypes
#len(avocado_cat_encoded.nunique())

# %%
# Define X values.
X = avocado_cat_encoded[[
 'month', 'week',
 'units_4046',
 'units_4225',
 'units_4770',
 's_bags',
 'l_bags',
 'xl_bags',
 'california',
 'chile',
 'mexico',
 'peru',
 'columbia',                                       
 'geography_Albany',
 'geography_Atlanta',
 'geography_Baltimore/Washington',
 'geography_Boise',
 'geography_Boston',
 'geography_Buffalo/Rochester',
 'geography_California',
 'geography_Charlotte',
 'geography_Chicago',
 'geography_Cincinnati/Dayton',
 'geography_Columbus',
 'geography_Dallas/Ft. Worth',
 'geography_Denver',
 'geography_Detroit',
 'geography_Grand Rapids',
 'geography_Great Lakes',
 'geography_Harrisburg/Scranton',
 'geography_Hartford/Springfield',
 'geography_Houston',
 'geography_Indianapolis',
 'geography_Jacksonville',
 'geography_Las Vegas',
 'geography_Los Angeles',
 'geography_Louisville',
 'geography_Miami/Ft. Lauderdale',
 'geography_Midsouth',
 'geography_Nashville',
 'geography_New Orleans/Mobile',
 'geography_New York',
 'geography_Northeast',
 'geography_Northern New England',
 'geography_Orlando',
 'geography_Philadelphia',
 'geography_Phoenix/Tucson',
 'geography_Pittsburgh',
 'geography_Plains',
 'geography_Portland',
 'geography_Raleigh/Greensboro',
 'geography_Richmond/Norfolk',
 'geography_Roanoke',
 'geography_Sacramento',
 'geography_San Diego',
 'geography_San Francisco',
 'geography_Seattle',
 'geography_South Carolina',
 'geography_South Central',
 'geography_Southeast',
 'geography_Spokane',
 'geography_St. Louis',
 'geography_Syracuse',
 'geography_Tampa',
 'geography_West',
 'geography_West Tex/New Mexico',
 'type_conventional',
 'type_organic',]]

# %%
# Define y values.
y = avocado_df_no_TotalUS.avg_price

# %%
# Split the to training and testing.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
# Fit the model.
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predict the model.
y_pred = model.predict(X_test)

# %%
# Mean squared error.
mean_squared_error(y_test, y_pred)
# Out:
# 0.04284549641054708

# %%
# R2 score.
r2_score(y_test, y_pred)
# Out:
# 0.6220771836452101

# %%
# Print coeficient and intercept
print(model.coef_)
print(model.intercept_)
# Out:
# [-3.82406028e-08  8.69048214e-03  4.05773280e-02 -9.40769516e-02
#   4.33870907e-02  1.89623980e-01  1.80817606e-01 -1.08309804e-01
#   2.10564089e-01  1.29900322e-01  1.45331958e-01 -9.42076419e-02
#  -1.84225174e-01 -2.71140571e-01 -3.95397178e-02 -1.49958091e-01
#   2.34008789e-03 -6.34031661e-02 -1.43407931e-01  3.32347727e-01
#  -2.33557797e-01 -1.78085101e-01 -9.64754649e-02 -9.76876682e-03
#   7.52765207e-02 -1.11494027e-01 -9.53118137e-02  2.22277868e-02
#  -1.43859059e-01 -2.16221230e-01  2.45558982e-01  1.70527641e-01
#   4.03919501e-02 -1.56184157e-01  3.08015099e-02 -1.66235525e-01
#  -8.76661505e-02 -7.74066967e-02  1.62758219e-01  1.95291885e-01
#  -1.60345995e-01 -1.35750502e-01  1.84000181e-01  1.65267619e-01
#   3.50374952e-01  2.89570550e-01 -3.94474918e-02 -1.69105545e-01
#  -4.59329356e-02  2.00561990e-01  1.18926873e-01 -8.03504972e-02
#  -1.60556783e-01  8.83622148e-02 -1.02764448e-01 -2.03048083e-01
#   2.03048087e-01]
# 1.3253662840575917

# %%
# Print the scores
print("R2 score : %.2f" % r2_score(y_test, y_pred))
print("Mean squared error: %.2f" % mean_squared_error(y_test,y_pred))
# Out:
# R2 score : 0.62
# Mean squared error: 0.04

# %% [markdown]
# ### Interpretation of the results
#
# **Intro**
#
# "R squared", is the proportion of the variance in the dependent variable that is predictable from the independent variable(s).
#
# Mean square error (MSE) is the average of the square of the errors. The larger the number the larger the error.
#
# There is no correct value for MSE. Simply put, the lower the value the better. Since there is no correct answer, the MSE’s basic value is in selecting one prediction model over another.
# Similarly, there is also no correct answer as to what R2 should be. 100% means perfect correlation. Yet, there are models with a low R2 that are still good models (Source: https://www.bmc.com/blogs/mean-squared-error-r2-and-variance-in-regression-analysis/ )
#
# Our dataset can be:
# Overfit means the model is subject to outliers and noise.
# Underfit means the model could look at other inputs (i.e., additional features).
#
# **Our Results**
#
# R2 score is on the higher side and tells that our model does quite well for the features that we used and that there is correlation amongst variables.
# Mean square error (MSE) is low, what tells that the error between observed and predicted is low.
#
# **Note**
#
# Model on only California and its cities did slightly better (it could be that larger data set has more outliers that might be skewing the results). also more noise in larger dataset. feature_importance different for all cities than only for CA.

# %% [markdown]
# ### Random Forest Regressor

# %%
# Initial imports.
import pandas as pd
from path import Path
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
# Train the model.
reg = RandomForestRegressor(n_estimators = 100, random_state = 0)
reg.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %%
y_pred = reg.predict(X_test)
#y_pred

# %%
# Print result mse and rmse (root mean squared error)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
rmse
# Out:
# 0.15990995425041082

# %% [markdown]
# #### Interpretaion of the results
# The RMSE is the square root of the variance of the residuals. It indicates the absolute fit of the model to the data–how close the observed data points are to the model’s predicted values. Whereas R-squared is a relative measure of fit, RMSE is an absolute measure of fit. As the square root of a variance, RMSE can be interpreted as the standard deviation of the unexplained variance, and has the useful property of being in the same units as the response variable. Lower values of RMSE indicate better fit. RMSE is a good measure of how accurately the model predicts the response, and it is the most important criterion for fit if the main purpose of the model is prediction.

# %%
# List the features sorted in descending order by feature importance
feature_importance = sorted(zip(reg.feature_importances_, X.columns), reverse=True)
feature_importance
# Out:
# [(0.2247770107772737, 'total_units_sold'),
#  (0.20423732758234414, 'type_organic'),
#  (0.19626438988821296, 'type_conventional'),
#  (0.08391991120755041, 'month'),
#  (0.017442068344155282, 'geography_San Francisco'),
#  (0.0172974306417913, 'geography_Hartford/Springfield'),
#  (0.015226250590603403, 'geography_Boise'),
#  (0.014316070693928542, 'geography_Spokane'),
#  (0.013609952062408946, 'geography_Seattle'),
#  (0.01215837112165799, 'geography_Houston'),
#  (0.012014056575428174, 'geography_Dallas/Ft. Worth'),
#  (0.011582756885331159, 'geography_Raleigh/Greensboro'),
#  (0.010278630004426461, 'geography_Phoenix/Tucson'),
#  (0.009673512964148248, 'geography_South Central'),
#  (0.009072347894735492, 'geography_San Diego'),
#  (0.008855222033242342, 'geography_New York'),
#  (0.008692568899205893, 'geography_Boston'),
#  (0.007160444836088517, 'geography_Sacramento'),
#  (0.007144381479150987, 'geography_St. Louis'),
#  (0.007030087218831141, 'geography_Portland'),
#  (0.006272927516231261, 'geography_Grand Rapids'),
#  (0.0061278336274289006, 'geography_Chicago'),
#  (0.006000007725313785, 'geography_West Tex/New Mexico'),
#  (0.00584360709538405, 'geography_Charlotte'),
#  (0.005123711835622787, 'geography_Northern New England'),
#  (0.004567998445208075, 'geography_Las Vegas'),
#  (0.004561436310868772, 'geography_Columbus'),
#  (0.004478995693689661, 'geography_Albany'),
#  (0.004110406793685688, 'geography_Louisville'),
#  (0.0038985210564095253, 'geography_Detroit'),
#  (0.003621845363297886, 'geography_Baltimore/Washington'),
#  (0.003609912460730915, 'geography_California'),
#  (0.0032255643480214357, 'geography_Jacksonville'),
#  (0.003223163796085934, 'geography_Cincinnati/Dayton'),
#  (0.0031941949167111536, 'geography_Nashville'),
#  (0.002962068084589611, 'geography_Northeast'),
#  (0.0027861443185385093, 'geography_Great Lakes'),
#  (0.002754476249685689, 'geography_New Orleans/Mobile'),
#  (0.0026981474776682965, 'geography_Denver'),
#  (0.0025131799132441287, 'geography_Roanoke'),
#  (0.0024912595126926193, 'geography_Pittsburgh'),
#  (0.0024786423909172383, 'geography_Los Angeles'),
#  (0.002349134070732519, 'geography_Richmond/Norfolk'),
#  (0.0023118945507334906, 'geography_Indianapolis'),
#  (0.002236028536386728, 'geography_Philadelphia'),
#  (0.0019277179412853322, 'geography_Atlanta'),
#  (0.0018575438294073361, 'geography_Tampa'),
#  (0.001778756760132829, 'geography_Miami/Ft. Lauderdale'),
#  (0.0014446087125386618, 'geography_Orlando'),
#  (0.0012897075799723674, 'geography_South Carolina'),
#  (0.0012604687169544516, 'geography_Buffalo/Rochester'),
#  (0.0012104033095777604, 'geography_Plains'),
#  (0.0011854925627453666, 'geography_West'),
#  (0.001150940543258401, 'geography_Syracuse'),
#  (0.0010333704127794918, 'geography_Harrisburg/Scranton'),
#  (0.0008578626480229202, 'geography_Midsouth'),
#  (0.0008092331929312659, 'geography_Southeast')]

# %% [markdown]
# ## Random Forest Classifier

# %%
# Import Dependencies
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced
from sklearn.model_selection import train_test_split
from imblearn.ensemble import BalancedRandomForestClassifier
from sklearn.metrics import confusion_matrix

# %%
# Descriptive statistics
avocado_cat_encoded.avg_price.describe()
# Out:
# count    14416.000000
# mean         1.361030
# std          0.342138
# min          0.500000
# 25%          1.110000
# 50%          1.330000
# 75%          1.570000
# max          2.780000
# Name: avg_price, dtype: float64

# %%
# Categorize y-values
labels = ["low", "low-medium", "high-medium","high"]
x = avocado_cat_encoded['avg_price']

#Categorize prices
avocado_cat_encoded["price_category"] = pd.qcut(x, 4, labels=labels)
avocado_cat_encoded.head()
# Out:
#      avg_price  total_volume_sold  units_4046  units_4225  units_4770  \
# 542       1.42           95246.38     2897.41    76570.67       44.00
# 543       1.47            4140.95        7.30      301.87        0.00
# 544       1.69          135196.35     3133.37   116520.88       88.78
# 545       1.54            3346.54       14.67      253.01        0.00
# 546       1.57           93625.03     3101.17    74627.23       55.59
#
#      total_bags    s_bags   l_bags  xl_bags  california  ...  \
# 542    15734.30  10012.80  5721.50     0.00    830821.0  ...
# 543     3831.78   3831.78     0.00     0.00    830821.0  ...
# 544    15453.32  10023.79  5429.53     0.00   2913663.0  ...
# 545     3078.86   3078.86     0.00     0.00   2913663.0  ...
# 546    15841.04  11614.79  4159.58    66.67   2698356.0  ...
#
#      geography_Spokane  geography_St. Louis  geography_Syracuse  \
# 542                  0                    0                   0
# 543                  0                    0                   0
# 544                  0                    0                   0
# 545                  0                    0                   0
# 546                  0                    0                   0
#
#      geography_Tampa  geography_West  geography_West Tex/New Mexico  \
# 542                0               0                              0
# 543                0               0                              0
# 544                0               0                              0
# 545                0               0                              0
# 546                0               0                              0
#
#      type_conventional  type_organic  status_actual  price_category
# 542                  1             0              1     high-medium
# 543                  0             1              1     high-medium
# 544                  1             0              1            high
# 545                  0             1              1     high-medium
# 546                  1             0              1     high-medium
#
# [5 rows x 75 columns]

# %%
# Check bin balance
avocado_cat_encoded["price_category"].value_counts()
# Out:
# low-medium     3665
# low            3627
# high           3567
# high-medium    3557
# Name: price_category, dtype: int64

# %%
# Assigning new X-values and y-values
y_new = avocado_cat_encoded["price_category"]
X_new = avocado_cat_encoded[[
 'month', 'week',
 'units_4046',
 'units_4225',
 'units_4770',
 's_bags',
 'l_bags',
 'xl_bags',
 'california',
 'chile',
 'mexico',
 'peru',
 'columbia',                                       
 'geography_Albany',
 'geography_Atlanta',
 'geography_Baltimore/Washington',
 'geography_Boise',
 'geography_Boston',
 'geography_Buffalo/Rochester',
 'geography_California',
 'geography_Charlotte',
 'geography_Chicago',
 'geography_Cincinnati/Dayton',
 'geography_Columbus',
 'geography_Dallas/Ft. Worth',
 'geography_Denver',
 'geography_Detroit',
 'geography_Grand Rapids',
 'geography_Great Lakes',
 'geography_Harrisburg/Scranton',
 'geography_Hartford/Springfield',
 'geography_Houston',
 'geography_Indianapolis',
 'geography_Jacksonville',
 'geography_Las Vegas',
 'geography_Los Angeles',
 'geography_Louisville',
 'geography_Miami/Ft. Lauderdale',
 'geography_Midsouth',
 'geography_Nashville',
 'geography_New Orleans/Mobile',
 'geography_New York',
 'geography_Northeast',
 'geography_Northern New England',
 'geography_Orlando',
 'geography_Philadelphia',
 'geography_Phoenix/Tucson',
 'geography_Pittsburgh',
 'geography_Plains',
 'geography_Portland',
 'geography_Raleigh/Greensboro',
 'geography_Richmond/Norfolk',
 'geography_Roanoke',
 'geography_Sacramento',
 'geography_San Diego',
 'geography_San Francisco',
 'geography_Seattle',
 'geography_South Carolina',
 'geography_South Central',
 'geography_Southeast',
 'geography_Spokane',
 'geography_St. Louis',
 'geography_Syracuse',
 'geography_Tampa',
 'geography_West',
 'geography_West Tex/New Mexico',
 'type_conventional',
 'type_organic',]]

# %%
# Split the to training and testing.
X_train, X_test, y_train, y_test = train_test_split(X_new, y_new, test_size=0.25, random_state=42)

# %%
# Resample the training data with the BalancedRandomForestClassifier
brf = BalancedRandomForestClassifier(n_estimators=100, random_state=1)
brf.fit(X_train, y_train)
# Out:
# BalancedRandomForestClassifier(random_state=1)

# %%
# Calculated the balanced accuracy score
y_pred = brf.predict(X_test)
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.7666937917230874

# %%
# Print the imbalanced classification report
from imblearn.metrics import classification_report_imbalanced
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#        high       0.82      0.86      0.94      0.84      0.90      0.80       865
# high-medium       0.68      0.69      0.89      0.68      0.79      0.61       885
#         low       0.83      0.87      0.94      0.85      0.90      0.81       901
#  low-medium       0.73      0.65      0.91      0.69      0.77      0.58       953
#
# avg / total       0.76      0.76      0.92      0.76      0.84      0.70      3604

# %%
# List the features sorted in descending order by feature importance
feature_importance = sorted(zip(brf.feature_importances_, X.columns), reverse=True)
for i in feature_importance:
    print('{} : ({})'.format(i[1], i[0]))
# Out:
# units_4046 : (0.11456429654303474)
# units_4225 : (0.10461731717887775)
# s_bags : (0.09465734649604685)
# l_bags : (0.08093944893058819)
# units_4770 : (0.06693250029789982)
# mexico : (0.05165641721500172)
# xl_bags : (0.04947339446804001)
# california : (0.048744563108734734)
# week : (0.044971568049515236)
# type_conventional : (0.041238028917277944)
# peru : (0.033982471771410984)
# month : (0.02783970254413508)
# chile : (0.025687832803108115)
# type_organic : (0.025398048386157314)
# columbia : (0.011617164306562037)
# geography_Baltimore/Washington : (0.005979442238810317)
# geography_San Francisco : (0.005909143357847429)
# geography_Hartford/Springfield : (0.005750330364949049)
# geography_Seattle : (0.005748962377200644)
# geography_New York : (0.004599559671240673)
# geography_Chicago : (0.004577645645823851)
# geography_Boston : (0.0043938152808436345)
# geography_Dallas/Ft. Worth : (0.004250763503192365)
# geography_Grand Rapids : (0.0042437745361463795)
# geography_Houston : (0.004130698518806828)
# geography_Indianapolis : (0.004036731359167865)
# geography_San Diego : (0.00402800118431901)
# geography_Richmond/Norfolk : (0.003994737894465906)
# geography_Northeast : (0.003949393747490567)
# geography_Sacramento : (0.003924227531436511)
# geography_South Central : (0.0038737048072470586)
# geography_Columbus : (0.0036861014655268564)
# geography_Louisville : (0.00367252833534039)
# geography_Philadelphia : (0.0036111809688341373)
# geography_Tampa : (0.0035478533978662383)
# geography_California : (0.0035450411073243843)
# geography_Phoenix/Tucson : (0.0035002496330981746)
# geography_Detroit : (0.0034436563203613544)
# geography_Spokane : (0.003406016626758345)
# geography_Harrisburg/Scranton : (0.0033479777692329788)
# geography_New Orleans/Mobile : (0.0033203629482541903)
# geography_Jacksonville : (0.0031248131307894584)
# geography_Portland : (0.0030527722976919636)
# geography_West Tex/New Mexico : (0.0029868606514348887)
# geography_Buffalo/Rochester : (0.0029731463305389992)
# geography_Raleigh/Greensboro : (0.0029473117454178153)
# geography_Orlando : (0.0029414865067097784)
# geography_Southeast : (0.0029278410408120187)
# geography_Plains : (0.0029161223135097665)
# geography_Boise : (0.002824410264148048)
# geography_Pittsburgh : (0.002715641903045528)
# geography_Northern New England : (0.002701101052460472)
# geography_Miami/Ft. Lauderdale : (0.0026984058096704766)
# geography_Roanoke : (0.0025815557995365955)
# geography_Nashville : (0.002553767160515911)
# geography_Syracuse : (0.002534626931994155)
# geography_Cincinnati/Dayton : (0.0025259883050477226)
# geography_St. Louis : (0.0025202197287546345)
# geography_Charlotte : (0.0025175511046605496)
# geography_Denver : (0.002510010134219612)
# geography_Las Vegas : (0.002381932374956967)
# geography_Midsouth : (0.0023517266764945697)
# geography_Los Angeles : (0.0022272074204120608)
# geography_Atlanta : (0.0021781562527449162)
# geography_Great Lakes : (0.0021199973979290606)
# geography_Albany : (0.002024513614528597)
# geography_South Carolina : (0.0019634289600620972)
# geography_West : (0.001407403483937724)

# %% [markdown]
# ### Neural Network ML model - in progress (Skeleton Code)

# %%
# # Import dependencies.
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import StandardScaler,OneHotEncoder
# import pandas as pd
# import tensorflow as tf
# from pathlib import Path

# import warnings
# warnings.filterwarnings('ignore')

# # Import checkpoint dependencies
# import os
# from tensorflow.keras.callbacks import ModelCheckpoint

# %%
# ## Visualize the value counts of avocado_mock_df['TBD']
# avocado_df = avocado_df['TBD'].value_counts()
# #ca_prod.plot(kind='bar')

# %%
# # Determine which values to replace if counts are less than ...?
# replace_ca_prod = list(ca_prod[ca_prod < 500000].index)

# ## Replace in dataframe
# for ca_p in replace_ca_prod:
#     avocado_mock_df['TBD'] = avocado_df['TBD'].replace(ca_p,"Other")
    
# # Check to make sure binning was successful
# avocado_df['TBD'].value_counts()

# %%
# # Generate our categorical variable lists
# avocado_cat = avocado_df.dtypes[avocado_mock_df.dtypes == "object"].index.tolist()

# %%
# # Create a OneHotEncoder instance
# enc = OneHotEncoder(sparse=False)

# # Fit and transform the OneHotEncoder using the categorical variable list
# encode_df = pd.DataFrame(enc.fit_transform(avocado_mock_df[avocado_cat]))

# # Add the encoded variable names to the dataframe
# encode_df.columns = enc.get_feature_names(avocado_cat)
# encode_df.head()

# %%
# # Merge one-hot encoded features and drop the originals
# avocado_df = avocado_df.merge(encode_df,left_index=True, right_index=True)
# avocado_df = avocado_df.drop(avocado_cat,1)
# avocado_df.head()

# %%
# # Split our preprocessed data into our features and target arrays
# y = avocado_df["TBD"].values
# X = avocado_df.drop(["TBD"],1).values

# # Split the preprocessed data into a training and testing dataset
# X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# # Create a StandardScaler instances
# scaler = StandardScaler()

# # Fit the StandardScaler
# X_scaler = scaler.fit(X_train)

# # Scale the data
# X_train_scaled = X_scaler.transform(X_train)
# X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ### Compile, Train and Evaluate the Model

# %%
# # Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
# number_input_features = len(X_train[0])
# hidden_nodes_layer1 = 210
# hidden_nodes_layer2 = 90
# #hidden_nodes_layer3 = 40

# nn = tf.keras.models.Sequential()

# # First hidden layer
# nn.add(
#     tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
# )

# # Second hidden layer
# nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# # Third hidden layer
# #nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="relu"))

# # Output layer
# nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# # Check the structure of the model
# nn.summary()

# %%
# # Define the checkpoint path and filenames
# os.makedirs("checkpoints/",exist_ok=True)
# checkpoint_path = "checkpoints/weights.{epoch:02d}.hdf5"

# %%
# # Compile the model
# nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# # Create a callback that saves the model's weights every 5 epochs
# cp_callback = ModelCheckpoint(
#     filepath=checkpoint_path,
#     verbose=1,
#     save_weights_only=True,
#     save_freq=1000)

# %%
# # Train the model
# fit_model = nn.fit(X_train_scaled,y_train,epochs=100,callbacks=[cp_callback])

# %%
# # Evaluate the model using the test data
# model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
# print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")

# %%
# Export our model to HDF5 file
#nn.save("Avocado_price.h5")
